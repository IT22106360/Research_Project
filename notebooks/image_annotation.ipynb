# %% [markdown]
# **Manual Annotation**

# %% [markdown]
# 000_000_022_2303_4.json

# %%
import json
from labels import LABELS  # 👈 import labels here

# %%
from pathlib import Path

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_000_022_2303_4.json")

# %%
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
len(data["tokens"]), len(data["bboxes"])
# Out:
# (49, 49)

# %%
data
# Out:
# {'image_id': '000_000_022_2303_4',
#  'tokens': ['potato',
#   'crisps',
#   'with',
#   'black',
#   'truffle',
#   'and',
#   'olive',
#   'oil',
#   '(0.02%)',
#   'seasoning',
#   'Serves/Portions:',
#   '5',
#   'Typical',
#   'values',
#   'Valeurs',
#   'moyennes',
#   'Energy',
#   'kJ',
#   'Energie',
#   'Energy',
#   'kcal',
#   'Energie',
#   'Fat/Matiéres',
#   'grasses',
#   'of',
#   'which',
#   'saturates',
#   'dont',
#   'acides',
#   'gras',
#   'saturés',
#   'Carbohydrate/Glucides',
#   'of',
#   'which',
#   'sugars',
#   'Gont',
#   'sucres',
#   '‘ference',
#   'intake',
#   '(adult)',
#   'Energy',
#   '8400kJ/2000kcal',
#   '10g',
#   'Saturates',
#   '20g',
#   'Sugars',
#   '90g',
#   'Salt',
#   '69g'],
#  'bboxes': [[39, 27, 184, 68],
#   [205, 22, 333, 68],
#   [353, 30, 443, 67],
#   [466, 32, 582, 68],
#   [601, 29, 743, 63],
#   [764, 37, 842, 69],
#   [865, 34, 970, 70],
#   [993, 31, 1048, 66],
#   [38, 85, 190, 131],
#   [213, 91, 432, 138],
# ...

# %%
labels = ["O"] * len(data["tokens"])

# %%
data
# Out:
# {'image_id': '000_000_022_2303_4',
#  'tokens': ['potato',
#   'crisps',
#   'with',
#   'black',
#   'truffle',
#   'and',
#   'olive',
#   'oil',
#   '(0.02%)',
#   'seasoning',
#   'Serves/Portions:',
#   '5',
#   'Typical',
#   'values',
#   'Valeurs',
#   'moyennes',
#   'Energy',
#   'kJ',
#   'Energie',
#   'Energy',
#   'kcal',
#   'Energie',
#   'Fat/Matiéres',
#   'grasses',
#   'of',
#   'which',
#   'saturates',
#   'dont',
#   'acides',
#   'gras',
#   'saturés',
#   'Carbohydrate/Glucides',
#   'of',
#   'which',
#   'sugars',
#   'Gont',
#   'sucres',
#   '‘ference',
#   'intake',
#   '(adult)',
#   'Energy',
#   '8400kJ/2000kcal',
#   '10g',
#   'Saturates',
#   '20g',
#   'Sugars',
#   '90g',
#   'Salt',
#   '69g'],
#  'bboxes': [[39, 27, 184, 68],
#   [205, 22, 333, 68],
#   [353, 30, 443, 67],
#   [466, 32, 582, 68],
#   [601, 29, 743, 63],
#   [764, 37, 842, 69],
#   [865, 34, 970, 70],
#   [993, 31, 1048, 66],
#   [38, 85, 190, 131],
#   [213, 91, 432, 138],
# ...

# %%
labels[0] = "B-INGREDIENT"
labels[1] = "I-INGREDIENT"
labels[2] = "O"
labels[3] = "B-INGREDIENT"
labels[4] = "I-INGREDIENT"
labels[5] = "O"
labels[6] = "B-INGREDIENT"
labels[7] = "I-INGREDIENT"

# %%
labels[8] = "B-CLAIMS"
labels[9] = "I-CLAIMS"

# %%
labels[16] = "B-NUTRIENT_NAME"
labels[17] = "I-NUTRIENT_NAME"

# %%
labels[18] = "B-NUTRIENT_NAME"
labels[19] = "I-NUTRIENT_NAME"
labels[20] = "I-NUTRIENT_NAME"
labels[21] = "I-NUTRIENT_NAME"

# %%
labels[22] = "B-NUTRIENT_NAME"
labels[23] = "I-NUTRIENT_NAME"
labels[26] = "B-NUTRIENT_NAME"
labels[30] = "I-NUTRIENT_NAME"
labels[31] = "B-NUTRIENT_NAME"
labels[34] = "B-NUTRIENT_NAME"
labels[36] = "I-NUTRIENT_NAME"
labels[40] = "B-NUTRIENT_NAME"
labels[41] = "B-CALORIES"
labels[42] = "B-NUTRIENT_VALUE"

labels[43] = "B-NUTRIENT_NAME"
labels[44] = "B-NUTRIENT_VALUE"

labels[45] = "B-NUTRIENT_NAME"
labels[46] = "B-NUTRIENT_VALUE"

labels[47] = "B-NUTRIENT_NAME"
labels[48] = "B-NUTRIENT_VALUE"

# %%
# -------------------------
# INGREDIENTS
# "potato crisps"
labels[0] = "B-INGREDIENT"
labels[1] = "E-INGREDIENT"

# "black truffle"
labels[3] = "B-INGREDIENT"
labels[4] = "E-INGREDIENT"

# "olive oil"
labels[6] = "B-INGREDIENT"
labels[7] = "E-INGREDIENT"

# -------------------------
# SERVING SIZE
# "Serves/Portions: 5"
labels[10] = "B-SERVING_SIZE"
labels[11] = "E-SERVING_SIZE"

# -------------------------
# NUTRIENT NAMES (Energy – kJ)
labels[16] = "B-NUTRIENT_NAME"   # Energy
labels[17] = "E-NUTRIENT_NAME"   # kJ

# -------------------------
# NUTRIENT NAMES (Energy – kcal)
labels[19] = "B-NUTRIENT_NAME"   # Energy
labels[20] = "E-NUTRIENT_NAME"   # kcal

# -------------------------
# NUTRIENT NAME
# "Fat/Matiéres grasses"
labels[22] = "B-NUTRIENT_NAME"
labels[23] = "E-NUTRIENT_NAME"

# -------------------------
# NUTRIENT NAME
# "of which saturates"
labels[24] = "B-NUTRIENT_NAME"
labels[25] = "I-NUTRIENT_NAME"
labels[26] = "E-NUTRIENT_NAME"

# -------------------------
# NUTRIENT NAME
# "Carbohydrate/Glucides"
labels[31] = "S-NUTRIENT_NAME"

# -------------------------
# NUTRIENT NAME
# "of which sugars"
labels[32] = "B-NUTRIENT_NAME"
labels[33] = "I-NUTRIENT_NAME"
labels[34] = "E-NUTRIENT_NAME"

# -------------------------
# CALORIES (Reference intake line)
labels[39] = "S-CALORIES"        # Energy
labels[40] = "S-CALORIES"        # 8400kJ/2000kcal

# -------------------------
# NUTRIENT VALUE ROWS
labels[41] = "B-NUTRIENT_NAME"   # 10g → Saturates value row header context
labels[42] = "S-NUTRIENT_VALUE"  # 10g

labels[43] = "S-NUTRIENT_NAME"   # Saturates
labels[44] = "S-NUTRIENT_VALUE"  # 20g

labels[45] = "S-NUTRIENT_NAME"   # Sugars
labels[46] = "S-NUTRIENT_VALUE"  # 90g

labels[47] = "S-NUTRIENT_NAME"   # Salt
labels[48] = "S-NUTRIENT_VALUE"  # 69g

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])

for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
print(LABELS)
# Out:
# ['O', 'B-INGREDIENT', 'I-INGREDIENT', 'E-INGREDIENT', 'S-INGREDIENT', 'B-NUTRIENT_NAME', 'I-NUTRIENT_NAME', 'E-NUTRIENT_NAME', 'S-NUTRIENT_NAME', 'B-NUTRIENT_VALUE', 'I-NUTRIENT_VALUE', 'E-NUTRIENT_VALUE', 'S-NUTRIENT_VALUE', 'B-SERVING_SIZE', 'I-SERVING_SIZE', 'E-SERVING_SIZE', 'S-SERVING_SIZE', 'B-CALORIES', 'I-CALORIES', 'E-CALORIES', 'S-CALORIES', 'B-CLAIMS', 'I-CLAIMS', 'E-CLAIMS', 'S-CLAIMS']

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_000_022_2303_4.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_000_057_6321_3

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_000_057_6321_3.json")

# %%
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
len(data["tokens"]), len(data["bboxes"])
# Out:
# (57, 57)

# %%
labels = ["O"] * len(data["tokens"])

# -------------------------
# INGREDIENT LIST
# -------------------------

labels[1] = "S-INGREDIENT"              # WATE (Water – OCR error)
labels[2] = "S-INGREDIENT"              # SALT,
labels[3] = "S-INGREDIENT"              # SPICES

# (MARJORAM BLACK PEPPER, MACE, GINGER, CORIANDER CARDAMOM, PIMENTO)
labels[4]  = "B-INGREDIENT"
labels[5]  = "I-INGREDIENT"
labels[6]  = "I-INGREDIENT"
labels[7]  = "I-INGREDIENT"
labels[8]  = "I-INGREDIENT"
labels[9]  = "I-INGREDIENT"
labels[10] = "E-INGREDIENT"

labels[11] = "S-INGREDIENT"             # DEXTROSE,

# MONO- AND DIGLYCERIDES OF FATTY ACIDS
labels[12] = "B-INGREDIENT"
labels[13] = "I-INGREDIENT"
labels[14] = "I-INGREDIENT"
labels[15] = "I-INGREDIENT"
labels[16] = "I-INGREDIENT"
labels[17] = "I-INGREDIENT"
labels[18] = "E-INGREDIENT"

# CITRIC ACID (ACIDIFIER)
labels[19] = "B-INGREDIENT"
labels[20] = "I-INGREDIENT"
labels[21] = "E-INGREDIENT"

# SPICE EXTRACTS.
labels[22] = "B-INGREDIENT"
labels[23] = "E-INGREDIENT"

# SODIUM PHOSPHATE.
labels[24] = "B-INGREDIENT"
labels[25] = "E-INGREDIENT"

# PORK CASING (PORK CASING. WATER, SALT)
labels[26] = "B-INGREDIENT"
labels[27] = "I-INGREDIENT"
labels[28] = "I-INGREDIENT"
labels[29] = "I-INGREDIENT"
labels[30] = "I-INGREDIENT"
labels[31] = "I-INGREDIENT"
labels[32] = "E-INGREDIENT"

# NISIN (FOR FRESHNESS)
labels[33] = "B-INGREDIENT"
labels[34] = "I-INGREDIENT"
labels[35] = "E-INGREDIENT"

# SODIUM CHLORIDE.
labels[36] = "B-INGREDIENT"
labels[37] = "E-INGREDIENT"

# %%
# -------------------------
# CLAIMS
# "DIST. AND SOLD EXCLUSIVELY BY: TRADER JOE'S, MONROVIA, CA 91016"
labels[38] = "B-CLAIMS"   # DIST.
labels[39] = "I-CLAIMS"   # AND
labels[40] = "I-CLAIMS"   # SOLD
labels[41] = "I-CLAIMS"   # EXCLUSIVELY
labels[42] = "I-CLAIMS"   # BY:
labels[43] = "I-CLAIMS"   # TRADER
labels[44] = "I-CLAIMS"   # JOE'S,
labels[45] = "I-CLAIMS"   # MONROVIA,
labels[46] = "I-CLAIMS"   # CA
labels[47] = "E-CLAIMS"   # 91016

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])

for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\000_000_057_6321_3.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_000_388_5305_2

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_000_388_5305_2.json")

# %%
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
len(data["tokens"]), len(data["bboxes"])
# Out:
# (5, 5)

# %%
labels = ["O"] * len(data["tokens"])

# -------------------------
# NUTRIENT NAME
# -------------------------
labels[4] = "S-NUTRIENT_NAME"   # Zucker (Sugar)

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])

for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_000_388_5305_2.json")

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_001_580_0763_2

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_001_580_0763_2.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (8, 8)

# %%
labels = ["O"] * len(data["tokens"])

# %%
data
# Out:
# {'image_id': '000_001_580_0763_2',
#  'tokens': ['341', '82', 'kcal', '51g', '1,19', '789', '3%', '19'],
#  'bboxes': [[1030, 502, 1167, 572],
#   [1015, 570, 1064, 666],
#   [1084, 573, 1167, 644],
#   [1065, 685, 1167, 758],
#   [1068, 831, 1167, 901],
#   [1065, 933, 1169, 1004],
#   [1313, 910, 1388, 973],
#   [863, 1130, 1170, 1218]]}

# %%
# -------------------------
# CALORIES
# "82 kcal"
labels[1] = "B-CALORIES"     # 82
labels[2] = "E-CALORIES"     # kcal

# -------------------------
# NUTRIENT VALUES (standalone values without visible names)
labels[3] = "S-NUTRIENT_VALUE"   # 51g
labels[4] = "S-NUTRIENT_VALUE"   # 1,19
labels[5] = "S-NUTRIENT_VALUE"   # 789
labels[6] = "S-NUTRIENT_VALUE"   # 3%

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_001_580_0763_2.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_001_647_2820_1

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_001_647_2820_1.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (17, 17)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# -------------------------
# INGREDIENTS
# -------------------------

labels[1] = "S-INGREDIENT"          # Water,

# Rice Flour
labels[2] = "B-INGREDIENT"
labels[3] = "E-INGREDIENT"

# Potato Flour
labels[4] = "B-INGREDIENT"
labels[5] = "E-INGREDIENT"

# Corn Starch
labels[6] = "B-INGREDIENT"
labels[7] = "E-INGREDIENT"

# Fibre
labels[9] = "S-INGREDIENT"

# Protein
labels[12] = "S-INGREDIENT"

# Rapeseed (oil) – OCR truncated
labels[13] = "B-INGREDIENT"
labels[14] = "E-INGREDIENT"

# Jodised Se (Jodised Salt / Selenium – truncated)
labels[15] = "B-INGREDIENT"
labels[16] = "E-INGREDIENT"

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_001_647_2820_1.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_001_821_8442_1

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_001_821_8442_1.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (35, 35)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# -------------------------
# CLAIMS
# -------------------------

# "Organic"
labels[17] = "S-CLAIMS"

# "made in a facility that also uses"
labels[20] = "B-CLAIMS"   # in
labels[21] = "I-CLAIMS"   # a
labels[22] = "I-CLAIMS"   # facility
labels[23] = "I-CLAIMS"   # that
labels[24] = "I-CLAIMS"   # also
labels[25] = "E-CLAIMS"   # uses

# "Gluten Free"
labels[29] = "B-CLAIMS"   # Gluten
labels[30] = "E-CLAIMS"   # Free

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_001_821_8442_1.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_002_000_9434_2

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_002_000_9434_2.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (131, 131)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# =================================================
# CLAIMS
# =================================================

# "From an MSC certified sustainable fishery."
labels[0] = "B-CLAIMS"      # From
labels[1] = "I-CLAIMS"      # an
labels[2] = "I-CLAIMS"      # MSC
labels[3] = "I-CLAIMS"      # certified
labels[4] = "I-CLAIMS"      # sustainable
labels[5] = "E-CLAIMS"      # fishery.

# =================================================
# INGREDIENTS
# =================================================

# "Herting Fillets (Fish)"
labels[8]  = "B-INGREDIENT"   # Herting
labels[9]  = "I-INGREDIENT"   # Fillets
labels[10] = "E-INGREDIENT"   # (Fish),

labels[11] = "S-INGREDIENT"   # Water,

labels[13] = "S-INGREDIENT"   # Pepper,
labels[14] = "S-INGREDIENT"   # Paprika,
labels[15] = "S-INGREDIENT"   # Salt,
labels[16] = "S-INGREDIENT"   # Sugar,
labels[17] = "S-INGREDIENT"   # Dextrose,

# "Beechwood Smoke"
labels[18] = "B-INGREDIENT"   # Beechwood
labels[19] = "E-INGREDIENT"   # Smoke,

# =================================================
# ALLERGEN / CROSS-CONTAMINATION CLAIM
# =================================================

# "May also contain Cereals containing Gluten, Celery, Mustard and Milk."
labels[25] = "B-CLAIMS"       # May
labels[26] = "I-CLAIMS"       # also
labels[27] = "I-CLAIMS"       # contain
labels[28] = "I-CLAIMS"       # Cereals
labels[29] = "I-CLAIMS"       # containing
labels[30] = "I-CLAIMS"       # Gluten,
labels[31] = "I-CLAIMS"       # Celery,
labels[32] = "I-CLAIMS"       # Mustard
labels[33] = "E-CLAIMS"       # and
labels[34] = "S-CLAIMS"       # Milk.

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_002_000_9434_2.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_002_002_2464_61

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_002_002_2464_61.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (31, 31)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# "pate de cacao"
labels[5] = "B-INGREDIENT"     # pate
labels[6] = "I-INGREDIENT"     # de
labels[7] = "E-INGREDIENT"     # cacao,

# "sucre"
labels[8] = "S-INGREDIENT"

# "beurre de cacao"
labels[9]  = "B-INGREDIENT"    # beurre
labels[10] = "I-INGREDIENT"    # de
labels[11] = "E-INGREDIENT"    # cacao,

# "cacao’en poudre fortement dégraissé"
labels[12] = "B-INGREDIENT"    # cacao’en
labels[13] = "I-INGREDIENT"    # poudre
labels[14] = "I-INGREDIENT"    # fortement
labels[15] = "E-INGREDIENT"    # dégraissé,

# "émulsifiant : lecithines (tournesol)"
labels[16] = "B-INGREDIENT"    # émulsifiant
labels[17] = "I-INGREDIENT"    # :
labels[18] = "I-INGREDIENT"    # lecithines
labels[19] = "E-INGREDIENT"    # (tournesol)

# "aréme naturel de Chocolat noir"
labels[21] = "B-INGREDIENT"    # aréme
labels[22] = "I-INGREDIENT"    # naturel
labels[23] = "I-INGREDIENT"    # de
labels[24] = "I-INGREDIENT"    # Chocolat
labels[25] = "E-INGREDIENT"    # noir

# %%
data["labels"] = labels

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_002_002_2464_61.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_002_012_3192_4

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_002_012_3192_4.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (34, 34)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# =================================================
# SUSTAINABILITY / ETHICAL CLAIM
# =================================================

labels[0]  = "B-CLAIMS"   # Tank
labels[1]  = "I-CLAIMS"   # pi
labels[2]  = "I-CLAIMS"   # i
labels[3]  = "I-CLAIMS"   # meegen
labels[4]  = "I-CLAIMS"   # |
labels[5]  = "I-CLAIMS"   # dag!
labels[6]  = "I-CLAIMS"   # Ved
labels[7]  = "I-CLAIMS"   # kab
labels[8]  = "I-CLAIMS"   # af
labels[9]  = "I-CLAIMS"   # dette
labels[10] = "I-CLAIMS"   # stpmer
labels[11] = "I-CLAIMS"   # du,
labels[12] = "I-CLAIMS"   # med
labels[13] = "I-CLAIMS"   # Lidl
labels[14] = "I-CLAIMS"   # Raindocest
labels[15] = "I-CLAIMS"   # Alliance
labels[16] = "I-CLAIMS"   # arbeider
labels[17] = "I-CLAIMS"   # for
labels[18] = "I-CLAIMS"   # at
labels[19] = "I-CLAIMS"   # bemme
labels[20] = "I-CLAIMS"   # 09
labels[21] = "I-CLAIMS"   # |
labels[22] = "I-CLAIMS"   # med
labels[23] = "I-CLAIMS"   # partnere
labels[24] = "I-CLAIMS"   # tager
labels[25] = "I-CLAIMS"   # Lidt
labels[26] = "I-CLAIMS"   # foe
labels[27] = "I-CLAIMS"   # mennesker
labels[28] = "I-CLAIMS"   # og
labels[29] = "I-CLAIMS"   # Mere
labels[30] = "I-CLAIMS"   # kan
labels[31] = "I-CLAIMS"   # findes
labels[32] = "I-CLAIMS"   # pi
labels[33] = "E-CLAIMS"   # ong.

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_002_012_3192_4.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_002_013_0732_18

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_002_013_0732_18.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (11, 11)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# "FREE RANGE WHOLE EGG"
labels[2] = "B-CLAIMS"    # RANGE
labels[3] = "I-CLAIMS"    # WHOLE
labels[4] = "E-CLAIMS"    # EGG

# "VEGETARIAN WITH EGG"
labels[5] = "B-CLAIMS"    # VEGETARIAN
labels[6] = "I-CLAIMS"    # WITH
labels[7] = "E-CLAIMS"    # EGG

# %%
data["labels"] = labels

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_002_013_0732_18.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)

# %% [markdown]
# 000_002_534_6657_5

# %%
json_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\cleaned_OCR\000_002_534_6657_5.json")
with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)
len(data["tokens"]), len(data["bboxes"])
# Out:
# (7, 7)

# %%
labels = ["O"] * len(data["tokens"])

# %%
# -------------------------
# INGREDIENTS
# -------------------------

labels[1] = "S-INGREDIENT"          # Maltodextrin,

# "Sucralose (1%)"
labels[2] = "B-INGREDIENT"          # Sucralose
labels[3] = "E-INGREDIENT"          # (1%),

# %%
data["labels"] = labels

# %%
assert len(data["tokens"]) == len(data["labels"])
for l in data["labels"]:
    assert l in LABELS, f"Invalid label: {l}"

# %%
output_path = Path(r"D:\Y4 Research\datasets\ocr_json\ing_nut_set1\new\annotated\min_conf=40\000_002_534_6657_5.json")
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2)
