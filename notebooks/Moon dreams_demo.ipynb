# %%
import torch
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_PATH = Path(r"C:\Models\Moondream")

assert MODEL_PATH.exists(), "Model folder does not exist!"

print("Loading tokenizer (local)...")
tokenizer = AutoTokenizer.from_pretrained(
    MODEL_PATH,
    trust_remote_code=True,
    local_files_only=True
)

print("Loading full Moondream model (local code)...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_PATH,
    trust_remote_code=True,
    local_files_only=True,   # 🔑 CRITICAL
    device_map={"": "cpu"},
    torch_dtype=torch.float32
)

model.eval()
print("✅ Full model loaded successfully")
# Out:
# Loading tokenizer (local)...
# Loading full Moondream model (local code)...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 17
#      10 tokenizer = AutoTokenizer.from_pretrained(
#      11     MODEL_PATH,
#      12     trust_remote_code=True,
#      13     local_files_only=True
#      14 )
#      16 print("Loading full Moondream model (local code)...")
# ---> 17 model = AutoModelForCausalLM.from_pretrained(
#      18     MODEL_PATH,
#      19     trust_remote_code=True,
#      20     local_files_only=True,   # 🔑 CRITICAL
#      21     device_map={"": "cpu"},
#      22     torch_dtype=torch.float32
#      23 )
#      25 model.eval()
#      26 print("✅ Full model loaded successfully")
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\models\auto\auto_factory.py:549, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     546 if kwargs.get("quantization_config") is not None:
#     547     _ = kwargs.pop("quantization_config")
# --> 549 config, kwargs = AutoConfig.from_pretrained(
#     550     pretrained_model_name_or_path,
#     551     return_unused_kwargs=True,
#     552     code_revision=code_revision,
#     553     _commit_hash=commit_hash,
#     554     **hub_kwargs,
#     555     **kwargs,
#     556 )
#     558 # if torch_dtype=auto was passed here, ensure to pass it on
#     559 if kwargs_orig.get("torch_dtype", None) == "auto":
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\models\auto\configuration_auto.py:1346, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1341     trust_remote_code = resolve_trust_remote_code(
#    1342         trust_remote_code, pretrained_model_name_or_path, has_local_code, has_remote_code, upstream_repo
#    1343     )
#    1345 if has_remote_code and trust_remote_code:
# -> 1346     config_class = get_class_from_dynamic_module(
#    1347         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1348     )
#    1349     config_class.register_for_auto_class()
#    1350     return config_class.from_pretrained(pretrained_model_name_or_path, **kwargs)
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\dynamic_module_utils.py:616, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     603 # And lastly we get the class inside our newly created module
#     604 final_module = get_cached_module_file(
#     605     repo_id,
#     606     module_file + ".py",
#    (...)    614     repo_type=repo_type,
#     615 )
# --> 616 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\dynamic_module_utils.py:299, in get_class_in_module(class_name, module_path, force_reload)
#     296 module_spec = importlib.util.spec_from_file_location(name, location=module_file)
#     298 # Hash the module file and all its relative imports to check if we need to reload it
# --> 299 module_files: list[Path] = [module_file] + sorted(map(Path, get_relative_import_files(module_file)))
#     300 module_hash: str = hashlib.sha256(b"".join(bytes(f) + f.read_bytes() for f in module_files)).hexdigest()
#     302 module: ModuleType
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\dynamic_module_utils.py:166, in get_relative_import_files(module_file)
#     164 new_imports = []
#     165 for f in files_to_check:
# --> 166     new_imports.extend(get_relative_imports(f))
#     168 module_path = Path(module_file).parent
#     169 new_import_files = [f"{str(module_path / m)}.py" for m in new_imports]
#
# File c:\Projects\Research_Project\env\Lib\site-packages\transformers\dynamic_module_utils.py:135, in get_relative_imports(module_file)
#     125 def get_relative_imports(module_file: Union[str, os.PathLike]) -> list[str]:
#     126     """
#     127     Get the list of modules that are relatively imported in a module file.
#     128
#    (...)    133         `list[str]`: The list of relative imports in the module.
#     134     """
# --> 135     with open(module_file, encoding="utf-8") as f:
#     136         content = f.read()
#     138     # Imports of the form `import .xxx`
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\rashm\\.cache\\huggingface\\modules\\transformers_modules\\Moondream\\layers.py'
